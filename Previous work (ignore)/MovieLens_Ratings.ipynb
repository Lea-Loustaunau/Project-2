# %% [markdown]
# Version 4 - Changes to use 'id' from movie_data and 'movieId' from ratings_data

# %%
import pandas as pd
import numpy as np

# %%
# Data Source 1 - movies_metadata 

movie_data = "Data/movies_metadata.csv"
movies_df = pd.read_csv(movie_data)
movies_df.columns
# Out:
# C:\Users\Lealo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# Drop all blank movie ID's

movies_df = movies_df.dropna(subset=['id'])

# %%
# Count null values in id

movies_df['id'].isna().sum()
# Out:
# 0

# %%
#movies_df['movieId'] = movies_df['id'].astype(str).astype(int)
#pd.to_numeric(movies_df['id'])
#movies_df.dtypes

# %%
s = movies_df['id']
s[19730]
# Out:
# 19970820

# %%
movies_df['id'] = movies_df['id'].astype(str).str.replace('\D+', '')

# %%
movies_df['id'] = movies_df['id'].apply(lambda x: int(x))
movies_df['id']
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45461    439050
# 45462    111109
# 45463     67758
# 45464    227506
# 45465    461257
# Name: id, Length: 45466, dtype: int64

# %% [markdown]
# # Data Source 2 - Ratings

# %%
# Data Source 2 - ratings 

ratings_data = "Data/ratings.csv"
ratings_df = pd.read_csv(ratings_data)
ratings_df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
ratings_df['movieId']
# Out:
# 0             110
# 1             147
# 2             858
# 3            1221
# 4            1246
#             ...
# 26024284    58559
# 26024285    60069
# 26024286    63082
# 26024287    64957
# 26024288    71878
# Name: movieId, Length: 26024289, dtype: int64

# %%
ratings_df.isna().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
ratings_df.where(ratings_df['movieId'] == 114709)
# Out:
#           userId  movieId  rating  timestamp
# 0            NaN      NaN     NaN        NaN
# 1            NaN      NaN     NaN        NaN
# 2            NaN      NaN     NaN        NaN
# 3            NaN      NaN     NaN        NaN
# 4            NaN      NaN     NaN        NaN
# ...          ...      ...     ...        ...
# 26024284     NaN      NaN     NaN        NaN
# 26024285     NaN      NaN     NaN        NaN
# 26024286     NaN      NaN     NaN        NaN
# 26024287     NaN      NaN     NaN        NaN
# 26024288     NaN      NaN     NaN        NaN
#
# [26024289 rows x 4 columns]

# %%
ratings_df.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
# ratings2_df = ratings_df.drop(['timestamp'], axis=1)

# %%
ratings_df.sort_values(by=['movieId'])
# Out:
#           userId  movieId  rating   timestamp
# 4560754    46848        1     4.0  1501544252
# 21804638  226491        1     4.0   918670493
# 21804572  226490        1     5.0  1454045658
# 11662860  121018        1     2.0  1451028121
# 2888413    30092        1     3.0   855598451
# ...          ...      ...     ...         ...
# 18234777  189131   176267     4.0  1501746426
# 9448563    97528   176269     3.5  1501764806
# 83813        837   176271     5.0  1501765780
# 25735653  267799   176273     1.0  1501769501
# 17181377  178373   176275     3.0  1501775968
#
# [26024289 rows x 4 columns]

# %%
ratingsfinal_df = ratings_df.groupby(['movieId'], as_index = False).mean()
ratingsfinal_df
# Out:
#        movieId         userId    rating     timestamp
# 0            1  135121.043616  3.888157  1.113440e+09
# 1            2  134877.953761  3.236953  1.088621e+09
# 2            3  136520.452733  3.175550  9.661124e+08
# 3            4  136249.536062  2.875713  9.390243e+08
# 4            5  135293.275855  3.079565  9.896788e+08
# ...        ...            ...       ...           ...
# 45110   176267  189131.000000  4.000000  1.501746e+09
# 45111   176269   97528.000000  3.500000  1.501765e+09
# 45112   176271     837.000000  5.000000  1.501766e+09
# 45113   176273  267799.000000  1.000000  1.501770e+09
# 45114   176275  178373.000000  3.000000  1.501776e+09
#
# [45115 rows x 4 columns]

# %%
ratingsfinal_df.dloc(8844)

# %% [markdown]
# # Transform

# %%
movies_df['rating'] = ""
ratings_list = []

for index, row in movies_df.iterrows():
    try:
        ratings_list = ratingsfinal_df.loc

# %%
movies_df['rating'] = movies_df.id.map(ratingsfinal_df.set_index('movieId')['rating'].to_dict())
movies_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
movies_df['rating'].isna().sum()
# Out:
# 37897
